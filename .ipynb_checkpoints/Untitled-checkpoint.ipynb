# %%
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn

# %%
df_fifa = pd.read_csv("./Datasets/FIFA/FIFA/FIFA_data.csv")
df_fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df_fifa.shape
# Out:
# (18207, 89)

# %%
player_india = df_fifa.loc[df_fifa["Nationality"] == "India"]
player_india.shape
# Out:
# (30, 89)

# %%
total_Indian_players = player_india["Name"].count()
total_Indian_players
# Out:
# 30

# %%
player_india.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
f,ax = plt.subplots(figsize = (25,15))
sns.heatmap(df_fifa.corr(),annot = True, linewidths=0.5, linecolor="red", fmt = '.1f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize = (25,15))
sns.heatmap(player_india.corr(),annot = True, linewidths=0.5, linecolor="blue", fmt = '.1f',ax=ax)
plt.show()

# By seeing the plot below, we can remove the international reputation of indian players

# %%
player_india.loc[player_india["Club"].isna()]
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 8605         8605  190939       S. Chhetri   33
# 10011       10011  223763       S. Jhingan   24
# 12598       12598  217225    J. Lalpekhlua   27
# 12811       12811  225213  G. Singh Sandhu   26
# 13508       13508  238205    A. Edathodika   31
# 14054       14054  231461        P. Halder   25
# 14199       14199  228188         P. Kotal   24
# 14218       14218  208485         L. Ralte   25
# 14705       14705  223764           N. Das   24
# 14786       14786  233524         U. Singh   22
# 14915       14915  228199       H. Narzary   24
# 15356       15356  212502         R. Singh   28
# 15643       15643  245166         S. Singh   22
# 15652       15652  245170         A. Thapa   20
# 15855       15855  234507       M. Rafique   25
# 15864       15864  223760         A. Singh   25
# 15884       15884  223771         B. Singh   31
# 16135       16135  245165          S. Bose   22
# ...

# %%
player_india = player_india.drop(['Photo','Club Logo'],axis = 1)

# %%
plt.bar( player_india['Age'],player_india['Overall'])
# Out:
# <BarContainer object of 30 artists>

# %%
plt.scatter(player_india["Penalties"],player_india["Volleys"])

# %%
player_india.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0      ID             Name  Age Nationality  \
# 8605         8605  190939       S. Chhetri   33       India
# 10011       10011  223763       S. Jhingan   24       India
# 12598       12598  217225    J. Lalpekhlua   27       India
# 12811       12811  225213  G. Singh Sandhu   26       India
# 13508       13508  238205    A. Edathodika   31       India
# 14054       14054  231461        P. Halder   25       India
# 14199       14199  228188         P. Kotal   24       India
# 14218       14218  208485         L. Ralte   25       India
# 14705       14705  223764           N. Das   24       India
# 14786       14786  233524         U. Singh   22       India
# 14915       14915  228199       H. Narzary   24       India
# 15356       15356  212502         R. Singh   28       India
# 15643       15643  245166         S. Singh   22       India
# 15652       15652  245170         A. Thapa   20       India
# ...

# %%
player_india.columns[player_india.isna().any()]
# Out:
# Index(['Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Release Clause'],
#       dtype='object')

# %%
player_india.fillna(0,inplace=True)
player_india.head()
# Out:
#        Unnamed: 0      ID             Name  Age Nationality  \
# 8605         8605  190939       S. Chhetri   33       India
# 10011       10011  223763       S. Jhingan   24       India
# 12598       12598  217225    J. Lalpekhlua   27       India
# 12811       12811  225213  G. Singh Sandhu   26       India
# 13508       13508  238205    A. Edathodika   31       India
#
#                                        Flag  Overall  Potential Value Wage  \
# 8605   https://cdn.sofifa.org/flags/159.png       67         67    €0   €0
# 10011  https://cdn.sofifa.org/flags/159.png       65         71    €0   €0
# 12598  https://cdn.sofifa.org/flags/159.png       63         64    €0   €0
# 12811  https://cdn.sofifa.org/flags/159.png       63         68    €0   €0
# 13508  https://cdn.sofifa.org/flags/159.png       62         62    €0   €0
#
#        ...  Composure Marking  StandingTackle  SlidingTackle GKDiving  \
# 8605   ...       67.0    30.0            24.0           44.0     10.0
# ...

# %%
def defending(data):
    return int(round((data[['Marking']])))
